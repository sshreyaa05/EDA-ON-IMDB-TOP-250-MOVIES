# %% [markdown]
# # EXPLORATORY DATA ANALYSIS ON IMDB TOP 250 MOVIES

# %% [markdown]
# ## IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## IMPORT THE IMDB TOP 250 MOVIES DATASET

# %%
df=pd.read_csv("IMDB Top 250 Movies.csv")
df
# Out:
#      rank                      name  year  rating                       genre  \
# 0       1  The Shawshank Redemption  1994     9.3                       Drama
# 1       2             The Godfather  1972     9.2                 Crime,Drama
# 2       3           The Dark Knight  2008     9.0          Action,Crime,Drama
# 3       4     The Godfather Part II  1974     9.0                 Crime,Drama
# 4       5              12 Angry Men  1957     9.0                 Crime,Drama
# ..    ...                       ...   ...     ...                         ...
# 245   246                  The Help  2011     8.1                       Drama
# 246   247               Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248                   Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249                    Gandhi  1982     8.0     Biography,Drama,History
# 249   250        Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
# ...

# %%
df.head()
# Out:
#    rank                      name  year  rating               genre  \
# 0     1  The Shawshank Redemption  1994     9.3               Drama
# 1     2             The Godfather  1972     9.2         Crime,Drama
# 2     3           The Dark Knight  2008     9.0  Action,Crime,Drama
# 3     4     The Godfather Part II  1974     9.0         Crime,Drama
# 4     5              12 Angry Men  1957     9.0         Crime,Drama
#
#   certificate run_time                                            tagline  \
# 0           R   2h 22m  Fear can hold you prisoner. Hope can set you f...
# 1           R   2h 55m                         An offer you can't refuse.
# 2       PG-13   2h 32m                                    Why So Serious?
# 3           R   3h 22m       All the power on earth can't change destiny.
# 4    Approved   1h 36m  Life Is In Their Hands -- Death Is On Their Mi...
#
#       budget  box_office                                              casts  \
# ...

# %% [markdown]
# ## STUDYING THE OUTLINE OF THE DATASET

# %%
df.tail()
# Out:
#      rank                name  year  rating                       genre  \
# 245   246            The Help  2011     8.1                       Drama
# 246   247         Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 247   248             Aladdin  1992     8.0  Animation,Adventure,Comedy
# 248   249              Gandhi  1982     8.0     Biography,Drama,History
# 249   250  Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
#     certificate run_time                                            tagline  \
# 245       PG-13   2h 26m                      Change begins with a whisper.
# 246           G   2h 22m  There is man and beast at nature's mercy. Ther...
# 247           G   1h 30m                     Wish granted! (DVD re-release)
# 248          PG   3h 11m             His Triumph Changed The World Forever.
# 249       PG-13    3h 1m  Inside everyone is a frontier waiting to be di...
#
#             budget     box_office  \
# 245       25000000      216639112
# ...

# %%
df.shape
# Out:
# (250, 13)

# %%
df.columns
# Out:
# Index(['rank', 'name', 'year', 'rating', 'genre', 'certificate', 'run_time',
#        'tagline', 'budget', 'box_office', 'casts', 'directors', 'writers'],
#       dtype='object')

# %%
df.size
# Out:
# 3250

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         250 non-null    int64
#  1   name         250 non-null    object
#  2   year         250 non-null    int64
#  3   rating       250 non-null    float64
#  4   genre        250 non-null    object
#  5   certificate  250 non-null    object
#  6   run_time     250 non-null    object
#  7   tagline      250 non-null    object
#  8   budget       250 non-null    object
#  9   box_office   250 non-null    object
#  10  casts        250 non-null    object
#  11  directors    250 non-null    object
#  12  writers      250 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 25.5+ KB

# %% [markdown]
# ## FINDING THE MISSING VALUES IN THE DATASET

# %%
df.isnull().sum()
# Out:
# rank           0
# name           0
# year           0
# rating         0
# genre          0
# certificate    0
# run_time       0
# tagline        0
# budget         0
# box_office     0
# casts          0
# directors      0
# writers        0
# dtype: int64

# %%
df.head().transpose()
# Out:
#                                                              0  \
# rank                                                         1
# name                                  The Shawshank Redemption
# year                                                      1994
# rating                                                     9.3
# genre                                                    Drama
# certificate                                                  R
# run_time                                                2h 22m
# tagline      Fear can hold you prisoner. Hope can set you f...
# budget                                                25000000
# box_office                                            28884504
# casts        Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# directors                                       Frank Darabont
# writers                            Stephen King,Frank Darabont
#
#                                                              1  \
# ...

# %%
df.describe()
# Out:
#              rank         year      rating
# count  250.000000   250.000000  250.000000
# mean   125.500000  1986.360000    8.307200
# std     72.312977    25.125356    0.229081
# min      1.000000  1921.000000    8.000000
# 25%     63.250000  1966.250000    8.100000
# 50%    125.500000  1994.000000    8.200000
# 75%    187.750000  2006.000000    8.400000
# max    250.000000  2022.000000    9.300000

# %% [markdown]
# ### as we can see that there are no missing values in the dataset , we can proceed further ....

# %% [markdown]
# ### as we can see that under the column "budget" we have some values addressed as  "not available", therefore,  we can drop those particular rows with those " not available" values.......

# %%
df_budget=df[df["budget"]=="Not Available"].index
df.drop(df_budget,inplace=True)
df.head(15)
# Out:
#     rank                                               name  year  rating  \
# 0      1                           The Shawshank Redemption  1994     9.3
# 1      2                                      The Godfather  1972     9.2
# 2      3                                    The Dark Knight  2008     9.0
# 3      4                              The Godfather Part II  1974     9.0
# 4      5                                       12 Angry Men  1957     9.0
# 5      6                                   Schindler's List  1993     9.0
# 6      7      The Lord of the Rings: The Return of the King  2003     9.0
# 7      8                                       Pulp Fiction  1994     8.9
# 8      9  The Lord of the Rings: The Fellowship of the Ring  2001     8.8
# 9     10                     The Good, the Bad and the Ugly  1966     8.8
# 10    11                                       Forrest Gump  1994     8.8
# 11    12                                         Fight Club  1999     8.8
# ...

# %% [markdown]
# ## now lets convert the budget into numeric....

# %%
df["budget"]=df["budget"].replace(" $"," ")
df["budget"]
# Out:
# 0       25000000
# 1        6000000
# 2      185000000
# 3       13000000
# 4         350000
#          ...
# 244     70000000
# 245     25000000
# 246      4000000
# 248     22000000
# 249     22000000
# Name: budget, Length: 211, dtype: object

# %%
df[df["budget"]=="RF\xa018000000"]
# Out:
# Empty DataFrame
# Columns: [rank, name, year, rating, genre, certificate, run_time, tagline, budget, box_office, casts, directors, writers]
# Index: []

# %%
df["budget"]=df["budget"].str.replace("RF\xa0"," ")
df[df["budget"]=="EM\xa08000000"]
# Out:
# Empty DataFrame
# Columns: [rank, name, year, rating, genre, certificate, run_time, tagline, budget, box_office, casts, directors, writers]
# Index: []

# %%
df["budget"]=df["budget"].str.replace("EM\xa0"," ")
df["budget"]=df["budget"].str.replace("$"," ")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3540\190976011.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["budget"]=df["budget"].str.replace("$"," ")

# %%
df["budget"]=df["budget"].astype(float)
df["budget"]
# Out:
# 0       25000000.0
# 1        6000000.0
# 2      185000000.0
# 3       13000000.0
# 4         350000.0
#           ...
# 244     70000000.0
# 245     25000000.0
# 246      4000000.0
# 248     22000000.0
# 249     22000000.0
# Name: budget, Length: 211, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         211 non-null    int64
#  1   name         211 non-null    object
#  2   year         211 non-null    int64
#  3   rating       211 non-null    float64
#  4   genre        211 non-null    object
#  5   certificate  211 non-null    object
#  6   run_time     211 non-null    object
#  7   tagline      211 non-null    object
#  8   budget       211 non-null    float64
#  9   box_office   211 non-null    object
#  10  casts        211 non-null    object
#  11  directors    211 non-null    object
#  12  writers      211 non-null    object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 23.1+ KB

# %% [markdown]
# ## so lets convert the box office into numeric or float

# %%
df[df["box_office"]=="Not Available"]
# Out:
# Empty DataFrame
# Columns: [rank, name, year, rating, genre, certificate, run_time, tagline, budget, box_office, casts, directors, writers]
# Index: []

# %%
df.transpose()
# Out:
#                                                            0    \
# rank                                                         1
# name                                  The Shawshank Redemption
# year                                                      1994
# rating                                                     9.3
# genre                                                    Drama
# certificate                                                  R
# run_time                                                2h 22m
# tagline      Fear can hold you prisoner. Hope can set you f...
# budget                                              25000000.0
# box_office                                            28884504
# casts        Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# directors                                       Frank Darabont
# writers                            Stephen King,Frank Darabont
#
#                                                            1    \
# ...

# %%
df["box_office"]=df["box_office"].str.replace("(estimated)" , "")
df["box_office"]
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3540\3194482741.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["box_office"]=df["box_office"].str.replace("(estimated)" , "")
# 0        28884504
# 1       250341816
# 2      1006234167
# 3        47961919
# 4             955
#           ...
# 244      23335817
# 245     216639112
# 246         14480
# 248      52767889
# 249     424208848
# Name: box_office, Length: 211, dtype: object

# %%
df["box_office"]= df["box_office"].replace("910000 ()" , "910000")
df["box_office"]
# Out:
# 0        28884504
# 1       250341816
# 2      1006234167
# 3        47961919
# 4             955
#           ...
# 244      23335817
# 245     216639112
# 246         14480
# 248      52767889
# 249     424208848
# Name: box_office, Length: 211, dtype: object

# %%
df["box_office"]=df["box_office"].replace("750000 ()" , "750000")
df["box_office"]
# Out:
# 0        28884504
# 1       250341816
# 2      1006234167
# 3        47961919
# 4             955
#           ...
# 244      23335817
# 245     216639112
# 246         14480
# 248      52767889
# 249     424208848
# Name: box_office, Length: 211, dtype: object

# %%
df["box_office"]= df["box_office"].replace("800000 ()" , "800000")
df["box_office"]
# Out:
# 0        28884504
# 1       250341816
# 2      1006234167
# 3        47961919
# 4             955
#           ...
# 244      23335817
# 245     216639112
# 246         14480
# 248      52767889
# 249     424208848
# Name: box_office, Length: 211, dtype: object

# %%
df[df["box_office"]=="()"]
# Out:
# Empty DataFrame
# Columns: [rank, name, year, rating, genre, certificate, run_time, tagline, budget, box_office, casts, directors, writers]
# Index: []

# %%
df["box_office"]= df["box_office"].astype(float)
df["box_office"]
# Out:
# 0      2.888450e+07
# 1      2.503418e+08
# 2      1.006234e+09
# 3      4.796192e+07
# 4      9.550000e+02
#            ...
# 244    2.333582e+07
# 245    2.166391e+08
# 246    1.448000e+04
# 248    5.276789e+07
# 249    4.242088e+08
# Name: box_office, Length: 211, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 211 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         211 non-null    int64
#  1   name         211 non-null    object
#  2   year         211 non-null    int64
#  3   rating       211 non-null    float64
#  4   genre        211 non-null    object
#  5   certificate  211 non-null    object
#  6   run_time     211 non-null    object
#  7   tagline      211 non-null    object
#  8   budget       211 non-null    float64
#  9   box_office   211 non-null    float64
#  10  casts        211 non-null    object
#  11  directors    211 non-null    object
#  12  writers      211 non-null    object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 31.2+ KB

# %% [markdown]
# ## now lets convert the run time into numeric

# %%
indexrun_time=df[df["run_time"]=="Not Available"].index
df.drop(indexrun_time,inplace=True)
df.head(15)
# Out:
#     rank                                               name  year  rating  \
# 0      1                           The Shawshank Redemption  1994     9.3
# 1      2                                      The Godfather  1972     9.2
# 2      3                                    The Dark Knight  2008     9.0
# 3      4                              The Godfather Part II  1974     9.0
# 4      5                                       12 Angry Men  1957     9.0
# 5      6                                   Schindler's List  1993     9.0
# 6      7      The Lord of the Rings: The Return of the King  2003     9.0
# 7      8                                       Pulp Fiction  1994     8.9
# 8      9  The Lord of the Rings: The Fellowship of the Ring  2001     8.8
# 9     10                     The Good, the Bad and the Ugly  1966     8.8
# 10    11                                       Forrest Gump  1994     8.8
# 11    12                                         Fight Club  1999     8.8
# ...

# %%
df[df["run_time"]=="Not Available"]
# Out:
# Empty DataFrame
# Columns: [rank, name, year, rating, genre, certificate, run_time, tagline, budget, box_office, casts, directors, writers]
# Index: []

# %%
df["run_time"]=df["run_time"].str.replace("h" , " ")
df["run_time"]
# Out:
# 0      2  22m
# 1      2  55m
# 2      2  32m
# 3      3  22m
# 4      1  36m
#         ...
# 244    1  26m
# 245    2  26m
# 246    2  22m
# 248    3  11m
# 249     3  1m
# Name: run_time, Length: 210, dtype: object

# %%
df["run_time"]=df["run_time"].str.replace("m" , " ")
df["run_time"]
# Out:
# 0      2  22
# 1      2  55
# 2      2  32
# 3      3  22
# 4      1  36
#         ...
# 244    1  26
# 245    2  26
# 246    2  22
# 248    3  11
# 249     3  1
# Name: run_time, Length: 210, dtype: object

# %%
df["run_time"]=df["run_time"].str.replace("  " , ".")
df["run_time"]
# Out:
# 0      2.22
# 1      2.55
# 2      2.32
# 3      3.22
# 4      1.36
#        ...
# 244    1.26
# 245    2.26
# 246    2.22
# 248    3.11
# 249     3.1
# Name: run_time, Length: 210, dtype: object

# %%
df["run_time"]=df["run_time"].astype(float)
df["run_time"]
# Out:
# 0      2.22
# 1      2.55
# 2      2.32
# 3      3.22
# 4      1.36
#        ...
# 244    1.26
# 245    2.26
# 246    2.22
# 248    3.11
# 249    3.10
# Name: run_time, Length: 210, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         210 non-null    int64
#  1   name         210 non-null    object
#  2   year         210 non-null    int64
#  3   rating       210 non-null    float64
#  4   genre        210 non-null    object
#  5   certificate  210 non-null    object
#  6   run_time     210 non-null    float64
#  7   tagline      210 non-null    object
#  8   budget       210 non-null    float64
#  9   box_office   210 non-null    float64
#  10  casts        210 non-null    object
#  11  directors    210 non-null    object
#  12  writers      210 non-null    object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 23.0+ KB

# %% [markdown]
# ## now as we can see that some rows having movies with their run time mentioned as "not available" ....so , lets remove those particular rows of these movies.....

# %% [markdown]
# ## finding any not available values under the column certificate

# %%
df[df["certificate"]=="Not Available"]
# Out:
# Empty DataFrame
# Columns: [rank, name, year, rating, genre, certificate, run_time, tagline, budget, box_office, casts, directors, writers]
# Index: []

# %% [markdown]
# ### so as we can see there's no not available values under certificate column

# %%
df["year"]=df["year"].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 210 entries, 0 to 249
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rank         210 non-null    int64
#  1   name         210 non-null    object
#  2   year         210 non-null    object
#  3   rating       210 non-null    float64
#  4   genre        210 non-null    object
#  5   certificate  210 non-null    object
#  6   run_time     210 non-null    float64
#  7   tagline      210 non-null    object
#  8   budget       210 non-null    float64
#  9   box_office   210 non-null    float64
#  10  casts        210 non-null    object
#  11  directors    210 non-null    object
#  12  writers      210 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 23.0+ KB

# %% [markdown]
# ## Now our data is ready for the exploratory data analysis

# %% [markdown]
# ## 1. out of 210 movies , which was the certificate that most of the movies have received?

# %%
df["certificate"].value_counts()
# Out:
# R            89
# PG-13        33
# PG           33
# G            16
# Approved     13
# Passed       12
# Not Rated     9
# 18+           1
# Unrated       1
# X             1
# 13+           1
# GP            1
# Name: certificate, dtype: int64

# %%
df["certificate"].value_counts().plot(kind="bar",color="green")
plt.show()

# %% [markdown]
# ## result:
# ### certificate R has been received by most of the movies

# %% [markdown]
# ## 2. which year had the most number of releases?

# %%
df["year"].value_counts()
# Out:
# 1995    7
# 2004    6
# 2003    6
# 1999    6
# 1994    5
#        ..
# 1972    1
# 1981    1
# 1931    1
# 1942    1
# 1934    1
# Name: year, Length: 81, dtype: int64

# %% [markdown]
# ## result:
# ### so we can say that the year 1995 had the most number of releases

# %% [markdown]
# ## 3. which were the top 4 genres under which most of the movies came in the top 250 movies?

# %%
top_4_genres=df["genre"].value_counts().head(4)
top_4_genres
# Out:
# Drama                         14
# Crime,Drama                   12
# Animation,Adventure,Comedy     8
# Biography,Drama,History        7
# Name: genre, dtype: int64

# %%
top_4_genres.value_counts().plot(kind="bar",color="magenta")
plt.show()

# %% [markdown]
# ## result:
# ### so the top 4 genres were:
# ### Drama                        : 14
# ### Crime,Drama                  : 12
# ### Animation,Adventure,Comedy   :  8
# ### Biography,Drama,History      :  7

# %% [markdown]
# ## 4. which movie had the highest budget and what were the top 8 movies with the highest budget?

# %%
top_8_high_budget=df.sort_values(by="budget",ascending=False).head(8)
top_8_high_budget
# Out:
#      rank                     name  year  rating                       genre  \
# 78     79        Princess Mononoke  1997     8.4  Animation,Action,Adventure
# 82     83                 3 Idiots  2009     8.4                Comedy,Drama
# 77     78        Avengers: Endgame  2019     8.4      Action,Adventure,Drama
# 62     63   Avengers: Infinity War  2018     8.4     Action,Adventure,Sci-Fi
# 68     69    The Dark Knight Rises  2012     8.4                Action,Drama
# 85     86              Toy Story 3  2010     8.3  Animation,Adventure,Comedy
# 149   150  Spider-Man: No Way Home  2021     8.2    Action,Adventure,Fantasy
# 2       3          The Dark Knight  2008     9.0          Action,Crime,Drama
#
#     certificate  run_time                                tagline  \
# 78        PG-13      2.14                               Live on.
# 82        PG-13      2.50      Don't be Stupid. Be an I.D.I.O.T.
# 77        PG-13      3.10                     Avenge the fallen.
# ...

# %% [markdown]
# ## result:
# ### as we can see that the movie "princess mononoke" had the highest budget of 2.5 billion

# %% [markdown]
# ## 5. which movie had the highest rating and which were the top 8 movies with the highest rating?

# %%
df["rating"].max()
# Out:
# 9.3

# %%
top_8_rating=df.sort_values(by="rating",ascending=False).head(8)
top_8_rating
# Out:
#    rank                                           name  year  rating  \
# 0     1                       The Shawshank Redemption  1994     9.3
# 1     2                                  The Godfather  1972     9.2
# 2     3                                The Dark Knight  2008     9.0
# 3     4                          The Godfather Part II  1974     9.0
# 4     5                                   12 Angry Men  1957     9.0
# 5     6                               Schindler's List  1993     9.0
# 6     7  The Lord of the Rings: The Return of the King  2003     9.0
# 7     8                                   Pulp Fiction  1994     8.9
#
#                      genre certificate  run_time  \
# 0                    Drama           R      2.22
# 1              Crime,Drama           R      2.55
# 2       Action,Crime,Drama       PG-13      2.32
# 3              Crime,Drama           R      3.22
# 4              Crime,Drama    Approved      1.36
# ...

# %% [markdown]
# ## result:
# ### as we can see that the movie "the shawshank redemption" had the highest rating of 9.3

# %% [markdown]
# ## 6. which movie had the longest runtime and what were the top 10 movies with the maximumum runtime?

# %%
longest_runtime_10= df.sort_values(by="run_time" , ascending=False)
longest_runtime_10
# Out:
#      rank                         name  year  rating  \
# 26     27               The Green Mile  1999     8.6
# 158   159           Gone with the Wind  1939     8.2
# 190   191                 Barry Lyndon  1975     8.1
# 79     80  Once Upon a Time in America  1984     8.3
# 96     97           Lawrence of Arabia  1962     8.3
# ..    ...                          ...   ...     ...
# 59     60               Paths of Glory  1957     8.4
# 51     52                  City Lights  1931     8.5
# 46     47                 Modern Times  1936     8.5
# 244   245               The Iron Giant  1999     8.1
# 73     74                    Toy Story  1995     8.3
#
#                           genre certificate  run_time  \
# 26          Crime,Drama,Fantasy           R      3.90
# 158           Drama,Romance,War      Passed      3.58
# 190         Adventure,Drama,War          PG      3.50
# 79                  Crime,Drama           R      3.49
# ...

# %% [markdown]
# ## result:
# ### so we can say that the movie "the green mile" has the longest run time of 3 hrs 90 mins

# %% [markdown]
# ## 7. what is the average budget of the top 250 movies in the dataset?

# %%
df["budget"].mean()
# Out:
# 52535562.66190476

# %% [markdown]
# ## result:
# ### the average budget of the top 250 movies is $52,535.562 or 52 million

# %% [markdown]
# ## 8. what were the top 8 highest grossing movies out of these top 250 movies?

# %%
top_8_gross=df.sort_values(by="box_office" , ascending=False).head(8)
top_8_gross
# Out:
#      rank                                           name  year  rating  \
# 77     78                              Avengers: Endgame  2019     8.4
# 62     63                         Avengers: Infinity War  2018     8.4
# 149   150                        Spider-Man: No Way Home  2021     8.2
# 105   106                              Top Gun: Maverick  2022     8.3
# 180   181   Harry Potter and the Deathly Hallows: Part 2  2011     8.1
# 6       7  The Lord of the Rings: The Return of the King  2003     9.0
# 143   144                                  Jurassic Park  1993     8.2
# 68     69                          The Dark Knight Rises  2012     8.4
#
#                         genre certificate  run_time  \
# 77     Action,Adventure,Drama       PG-13      3.10
# 62    Action,Adventure,Sci-Fi       PG-13      2.29
# 149  Action,Adventure,Fantasy       PG-13      2.28
# 105              Action,Drama       PG-13      2.10
# 180  Adventure,Family,Fantasy       PG-13      2.10
# ...

# %% [markdown]
# ## result:
# ### as we can see that the avengers end game has grossed the highest with 356 billion

# %% [markdown]
# ## 9. which was the highest rated movie under genre "drama"?

# %%
genre_drama=df[df["genre"]=="Drama"]
genre_drama
# Out:
#      rank                             name  year  rating  genre certificate  \
# 0       1         The Shawshank Redemption  1994     9.3  Drama           R
# 11     12                       Fight Club  1999     8.8  Drama           R
# 17     18  One Flew Over the Cuckoo's Nest  1975     8.7  Drama         18+
# 66     67                  American Beauty  1999     8.4  Drama           R
# 84     85              Requiem for a Dream  2000     8.3  Drama     Unrated
# 113   114                     A Separation  2011     8.3  Drama       PG-13
# 120   121                  Bicycle Thieves  1948     8.3  Drama   Not Rated
# 130   131                    All About Eve  1950     8.2  Drama      Passed
# 138   139              There Will Be Blood  2007     8.2  Drama           R
# 166   167                    Trainspotting  1996     8.1  Drama           R
# 170   171                      Gran Torino  2008     8.1  Drama           R
# ...

# %%
genre_drama.sort_values(by="rating",ascending=False).head(8)
# Out:
#      rank                             name  year  rating  genre certificate  \
# 0       1         The Shawshank Redemption  1994     9.3  Drama           R
# 11     12                       Fight Club  1999     8.8  Drama           R
# 17     18  One Flew Over the Cuckoo's Nest  1975     8.7  Drama         18+
# 66     67                  American Beauty  1999     8.4  Drama           R
# 84     85              Requiem for a Dream  2000     8.3  Drama     Unrated
# 113   114                     A Separation  2011     8.3  Drama       PG-13
# 120   121                  Bicycle Thieves  1948     8.3  Drama   Not Rated
# 130   131                    All About Eve  1950     8.2  Drama      Passed
#
#      run_time                                            tagline      budget  \
# 0        2.22  Fear can hold you prisoner. Hope can set you f...  25000000.0
# 11       2.19  How much can you know about yourself if you've...  63000000.0
# ...

# %% [markdown]
# ## result:
# ### so the movie "the shawshank redemption" has the highest rating of 9.3 under  genre drama

# %% [markdown]
# ## 10. which drama genre has the highest box office collection?

# %%
genre_drama_collection= df[df["genre"]=="Drama"]
genre_drama_collection
# Out:
#      rank                             name  year  rating  genre certificate  \
# 0       1         The Shawshank Redemption  1994     9.3  Drama           R
# 11     12                       Fight Club  1999     8.8  Drama           R
# 17     18  One Flew Over the Cuckoo's Nest  1975     8.7  Drama         18+
# 66     67                  American Beauty  1999     8.4  Drama           R
# 84     85              Requiem for a Dream  2000     8.3  Drama     Unrated
# 113   114                     A Separation  2011     8.3  Drama       PG-13
# 120   121                  Bicycle Thieves  1948     8.3  Drama   Not Rated
# 130   131                    All About Eve  1950     8.2  Drama      Passed
# 138   139              There Will Be Blood  2007     8.2  Drama           R
# 166   167                    Trainspotting  1996     8.1  Drama           R
# 170   171                      Gran Torino  2008     8.1  Drama           R
# ...

# %%
genre_drama_collection.sort_values(by="box_office" , ascending=False).head(10)
# Out:
#      rank                             name  year  rating  genre certificate  \
# 66     67                  American Beauty  1999     8.4  Drama           R
# 170   171                      Gran Torino  2008     8.1  Drama           R
# 245   246                         The Help  2011     8.1  Drama       PG-13
# 17     18  One Flew Over the Cuckoo's Nest  1975     8.7  Drama         18+
# 11     12                       Fight Club  1999     8.8  Drama           R
# 138   139              There Will Be Blood  2007     8.2  Drama           R
# 0       1         The Shawshank Redemption  1994     9.3  Drama           R
# 218   219                          Network  1976     8.1  Drama           R
# 113   114                     A Separation  2011     8.3  Drama       PG-13
# 166   167                    Trainspotting  1996     8.1  Drama           R
#
#      run_time                                            tagline      budget  \
# ...

# %% [markdown]
# ## result:
# ### american beauty is the highest grossing drama genre with 356 million

# %% [markdown]
# ## 11. do high budget lead to high box office collection , do they have any significant relationship?

# %%
x=df["budget"]
y=df["box_office"]
plt.scatter(x,y,color="red")
plt.show()

# %% [markdown]
# ## result:
# ### from this visualisation we had come to know that the budget has no significant relation with box office collections

# %% [markdown]
# ## 12. which director had the highest box office collection?

# %%
director_gross= df.groupby("directors")["box_office"].sum().sort_values(ascending=False)
director_gross
# Out:
# directors
# Anthony Russo,Joe Russo    4.851854e+09
# Christopher Nolan          4.221516e+09
# Steven Spielberg           3.254923e+09
# Peter Jackson              2.992606e+09
# Jon Watts                  1.921847e+09
#                                ...
# Ingmar Bergman             3.112120e+05
# John Sturges               2.281780e+05
# Joseph L. Mankiewicz       1.510520e+05
# Stanley Kramer             1.218000e+04
# Stuart Rosenberg           6.700000e+01
# Name: box_office, Length: 131, dtype: float64

# %% [markdown]
# ## result:
# ### as we can see that Anthony Russo and Joe Russo has the highest box office collection of 4.85 billion dollars

# %% [markdown]
# ## 13. which genre has the highest box office collection and which year it had the highest box office collection?

# %%
genre_high_boxoffice=df[["genre" , "box_office" , "year"]].groupby(["genre" , "box_office"]).sum().sort_values(by="box_office" , ascending=False)


genre_high_boxoffice
# Out:
#                                        year
# genre                    box_office
# Action,Adventure,Drama   2.799439e+09  2019
# Action,Adventure,Sci-Fi  2.052415e+09  2018
# Action,Adventure,Fantasy 1.921847e+09  2021
# Action,Drama             1.488733e+09  2022
# Adventure,Family,Fantasy 1.342360e+09  2011
# ...                                     ...
# Comedy,Romance           1.147700e+04  1934
# Crime,Drama,Mystery      7.693000e+03  1957
# Drama,War                5.252000e+03  1957
# Crime,Drama              9.550000e+02  1957
#                          6.700000e+01  1967
#
# [210 rows x 1 columns]

# %% [markdown]
# ## result:
# ### so as we can see that genres "action" , "adventure" & "drama" has the highest box office collection in the year 2019 with 2.7994 billion dollars

# %% [markdown]
# ## 14. which year has the highest box office collection with all the movies released in that year?

# %%
year_high= df.groupby("year")["box_office"].sum().sort_values(ascending=False)
year_high.head(20)
# Out:
# year
# 2019    4.746562e+09
# 2003    2.939854e+09
# 2010    2.700638e+09
# 2018    2.374168e+09
# 2001    2.324648e+09
# 2011    2.031822e+09
# 2021    1.921847e+09
# 1994    1.909121e+09
# 1999    1.907673e+09
# 2008    1.797504e+09
# 2017    1.596378e+09
# 2012    1.507244e+09
# 1993    1.503072e+09
# 2022    1.488733e+09
# 2015    1.408201e+09
# 2004    1.286007e+09
# 1995    1.267865e+09
# 2009    1.118560e+09
# 2002    1.098698e+09
# 2014    9.963462e+08
# Name: box_office, dtype: float64

# %% [markdown]
# ## result:
# ### as we can see that 2019 has the highest box office collection of 4.746 billion

# %% [markdown]
# ## 15. is there any significant relation between box office collections and the ratings?

# %%
x=df["box_office"]
y=df["rating"]
plt.scatter(x,y,color="green")
plt.show()

# %% [markdown]
# ## result:
# ### no, as we can see there is no significant relation between box office collection and ratings

# %% [markdown]
# ## 16. do budget and box office collection have any outliers?

# %%
plt.boxplot([df["budget"], df["box_office"]])
plt.show()

# %% [markdown]
# ## result:
# ### yes,  as we can that the budget and box office has a few outliers

# %% [markdown]
# ## 17. what is the run time of the movie with the highest gross?

# %%
df.groupby(["run_time"])["box_office"].sum().sort_values(ascending=False).head(8)
# Out:
# run_time
# 2.10    4.324371e+09
# 3.10    3.223648e+09
# 2.28    2.815371e+09
# 2.20    2.614792e+09
# 2.29    2.118305e+09
# 2.70    1.911308e+09
# 2.17    1.348478e+09
# 1.43    1.333435e+09
# Name: box_office, dtype: float64

# %%
df.groupby(["run_time"])["box_office"].sum().sort_values(ascending=False).head(8).plot(kind="bar",color="violet")
plt.show()

# %% [markdown]
# ## result:
# ### the run time of the movie with the highest gross is 2hrs 10mins

# %% [markdown]
# ## 18. find the correlation of all the numeric variables.

# %%
df.corr()

# %%
df1=df[["rank" , "rating" , "run_time" , "budget" , "box_office"]]
df1
# Out:
#      rank  rating  run_time       budget    box_office
# 0       1     9.3      2.22   25000000.0  2.888450e+07
# 1       2     9.2      2.55    6000000.0  2.503418e+08
# 2       3     9.0      2.32  185000000.0  1.006234e+09
# 3       4     9.0      3.22   13000000.0  4.796192e+07
# 4       5     9.0      1.36     350000.0  9.550000e+02
# ..    ...     ...       ...          ...           ...
# 244   245     8.1      1.26   70000000.0  2.333582e+07
# 245   246     8.1      2.26   25000000.0  2.166391e+08
# 246   247     8.2      2.22    4000000.0  1.448000e+04
# 248   249     8.0      3.11   22000000.0  5.276789e+07
# 249   250     8.0      3.10   22000000.0  4.242088e+08
#
# [210 rows x 5 columns]

# %%
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %% [markdown]
# ## result:
# ### budget and box office collection has a correlation of 0.25
# ### rating and box office collection has a minor correlation of 0.16
# ### rating and run time has a correlation of 0.15
# ### rating and rank has a negative correlation

# %% [markdown]
# ## 19. which genre has the highest box office collection?

# %%
df.groupby("genre")["box_office"].sum().sort_values(ascending=False).head(10)

# %%
df.groupby("genre")["box_office"].sum().sort_values(ascending=False).head(10).plot(kind="bar",color="orange",title="genre v/s box_office")
plt.show()

# %% [markdown]
# ## result:
# ### among all the genres action adventure and drama has the highest box office collection

# %% [markdown]
# ## 20. what is the average ratings by genre?

# %%
avg_rate=df.groupby("genre").mean().sort_values(by="rating" , ascending=False).head(10)
avg_rate

# %% [markdown]
# ## result:
# ### as we can see that the adventure and western genres has the highest IMDB rating among all the genres
